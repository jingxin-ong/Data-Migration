# %%
import pandas as pd
import sys
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/mydatabase')

# %% [markdown]
# ### Converting CSV into SQL table

# %%
df = pd.read_csv('cleaned_fp_oct2020(with_kcc_answer).csv')
df.to_sql('farmpulse', engine)

# %%
df
# Out:
#           Unnamed: 0           created_on   state_name  \
# 0                  0  2009-12-17 00:00:00  maharashtra
# 1                  1  2010-01-01 00:00:00    rajasthan
# 2                  2  2010-01-01 00:00:00       punjab
# 3                  3  2010-01-01 00:00:00       punjab
# 4                  4  2010-01-01 00:00:00       punjab
# ...              ...                  ...          ...
# 15054001    15123797           2019-03-01   tamil nadu
# 15054002    15123798           2019-03-01   tamil nadu
# 15054003    15123799           2019-03-01   tamil nadu
# 15054004    15123800           2019-03-01   tamil nadu
# 15054005    15123801           2019-03-01  maharashtra
#
#                                                  crop  \
# 0                                              others
# 1         indian rapeseed and mustard (yellow sarson)
# 2                                               wheat
# 3                                               wheat
# ...

# %% [markdown]
# ### Size and Dimensions of FarmPulse Dataframe

# %%
print(f'num of entries: {df.size}')
print(f'num of rows: {df.shape[0]}')
print(f'num of columns: {df.shape[1]}')
print(f'memory required: {sys.getsizeof(df)} bytes')
# Out:
# num of entries: 105378042
# num of rows: 15054006
# num of columns: 7
# memory required: 7658006487 bytes

# %% [markdown]
# ### Generating a Test Sample

# %%
# extract first 100 rows
sample = df.head(100)
sample
# Out:
#     Unnamed: 0           created_on     state_name  \
# 0            0  2009-12-17 00:00:00    maharashtra
# 1            1  2010-01-01 00:00:00      rajasthan
# 2            2  2010-01-01 00:00:00         punjab
# 3            3  2010-01-01 00:00:00         punjab
# 4            4  2010-01-01 00:00:00         punjab
# ..         ...                  ...            ...
# 95          95  2010-01-01 08:52:24    maharashtra
# 96          96  2010-01-01 09:06:00        gujarat
# 97          97  2010-01-01 09:26:00        gujarat
# 98          98  2010-01-01 10:09:09          bihar
# 99          99  2010-01-01 10:18:50  uttar pradesh
#
#                                            crop  \
# 0                                        others
# 1   indian rapeseed and mustard (yellow sarson)
# 2                                         wheat
# 3                                         wheat
# 4                                         wheat
# ..                                          ...
# ...

# %%
sample.to_csv('testsample.csv', index = False)
