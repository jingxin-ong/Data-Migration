# %%
import os
import boto3
import botocore
import logging
from functools import lru_cache
import multiprocess as mp
import time

# %%
def aws_session(aws_profile=None):
    """Create a a boto3 session.
    Params:
        (string): credentials profile name
    Returns:
        (boto3 client object)
    """
    session = boto3.Session()
    # If the session is run on a local machine, with AWS credentials fetched
    # from a shared file, use the DataScience role profile.
    if session.get_credentials().method == 'shared-credentials-file':
        session = boto3.Session(profile_name=aws_profile)
    creds = session.get_credentials()
    result={
        'aws_access_key_id': creds.access_key,
        'aws_secret_access_key': creds.secret_key,
        'aws_session_token': creds.token
    }
    return result
CREDS = aws_session()
@lru_cache()
def s3_client():
    """Cache a boto3 client with credentias and MFA token."""
    return boto3.client(
            service_name='s3',
            aws_access_key_id=CREDS['aws_access_key_id'],
            aws_secret_access_key=CREDS['aws_secret_access_key'],
            aws_session_token=CREDS['aws_session_token'],
            config = botocore.client.Config(max_pool_connections = 50)
    )

# %%
class Migration:
    for handler in logging.root.handlers[:]:
        logging.root.removeHandler(handler)
    logging.basicConfig(filename='s3_transfer.log', level=logging.INFO)

    def __init__(self, src, dest, client):
        self.src = src
        self.dest = dest
        self.client = client

    def download(self, key):
        '''Downloads file from src bucket.'''
        try:
            logging.info("%s is being downloaded", key)
            local_file = os.path.abspath(key)
            current_dir = os.path.split(local_file)[0]
            if not os.path.exists(current_dir):
                os.makedirs(current_dir)
            self.client.download_file(self.src, key, local_file)
            logging.info("%s downloaded successfully", key)
        except Exception as ex:
            logging.exception(ex)

    def upload(self, key):
        '''Uploads file to dest bucket.'''
        try:
            logging.info("%s is being uploaded", key)
            local_file = os.path.abspath(key)
            # upload into a copy of the file
            key = key.split('/')[-2] + '_copy/' + key.split('/')[-1]
            self.client.upload_file(local_file, self.dest, key)
            logging.info("%s uploaded successfully", key)
        except Exception as ex:
            logging.exception(ex)

    def transfer(self, keys):
        '''Copies file from src bucket to dest bucket.'''
        start_time = time.time()
        logging.info("Transferring...")

        pool = mp.Pool(5)
        pool.map(self.download, keys)
        pool.map(self.upload, keys)

        logging.info('Transfer completed')
        time_taken = time.time() - start_time
        logging.info("took %s to run", time_taken)

# %%
s3b = s3_client()
s3_100_keys = []
response = s3b.list_objects_v2(Bucket='yara-sh-dads-scd', 
                                MaxKeys=100)
for content in response['Contents']:
    key = content['Key']
    s3_100_keys += [key] if not key[-1] == '/' else []

# %%
src = "yara-sh-dads-scd"
dest = "yara-sh-dads-scd-stage"
test_migrate = Migration(src, dest, s3b)
test_migrate.transfer(s3_100_keys)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-5-94de615a9900> in <module>
#       2 dest = "yara-sh-dads-scd-stage"
#       3 test_migrate = Migration(src, dest, s3b)
# ----> 4 test_migrate.transfer(s3_100_keys)
#
# <ipython-input-4-9dba73916965> in transfer(self, keys)
#      40
#      41         pool = mp.Pool(5)
# ---> 42         pool.map(self.download, keys)
#      43         pool.map(self.upload, keys)
#      44
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/multiprocess/pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/multiprocess/pool.py in _handle_tasks(taskqueue, put, outqueue, pool, cache)
#     535                         break
#     536                     try:
# --> 537                         put(task)
#     538                     except Exception as e:
#     539                         job, idx = task[:2]
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/multiprocess/connection.py in send(self, obj)
#     207         self._check_closed()
#     208         self._check_writable()
# --> 209         self._send_bytes(_ForkingPickler.dumps(obj))
#     210
#     211     def recv_bytes(self, maxlength=None):
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/multiprocess/reduction.py in dumps(cls, obj, protocol, *args, **kwds)
#      52     def dumps(cls, obj, protocol=None, *args, **kwds):
#      53         buf = io.BytesIO()
# ---> 54         cls(buf, protocol, *args, **kwds).dump(obj)
#      55         return buf.getbuffer()
#      56
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/dill/_dill.py in dump(self, obj)
#     452             raise PicklingError(msg)
#     453         else:
# --> 454             StockPickler.dump(self, obj)
#     455         stack.clear()  # clear record of 'recursion-sensitive' pickled objects
#     456         return
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in dump(self, obj)
#     485         if self.proto >= 4:
#     486             self.framer.start_framing()
# --> 487         self.save(obj)
#     488         self.write(STOP)
#     489         self.framer.end_framing()
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_tuple(self, obj)
#     899         write(MARK)
#     900         for element in obj:
# --> 901             save(element)
#     902
#     903         if id(obj) in memo:
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_tuple(self, obj)
#     884         if n <= 3 and self.proto >= 2:
#     885             for element in obj:
# --> 886                 save(element)
#     887             # Subtle.  Same as in the big comment below.
#     888             if id(obj) in memo:
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_tuple(self, obj)
#     884         if n <= 3 and self.proto >= 2:
#     885             for element in obj:
# --> 886                 save(element)
#     887             # Subtle.  Same as in the big comment below.
#     888             if id(obj) in memo:
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/dill/_dill.py in save_instancemethod0(pickler, obj)
#    1125     log.info("Me: %s" % obj) #XXX: obj.__dict__ handled elsewhere?
#    1126     if PY3:
# -> 1127         pickler.save_reduce(MethodType, (obj.__func__, obj.__self__), obj=obj)
#    1128     else:
#    1129         pickler.save_reduce(MethodType, (obj.im_func, obj.im_self,
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690         else:
#     691             save(func)
# --> 692             save(args)
#     693             write(REDUCE)
#     694
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_tuple(self, obj)
#     884         if n <= 3 and self.proto >= 2:
#     885             for element in obj:
# --> 886                 save(element)
#     887             # Subtle.  Same as in the big comment below.
#     888             if id(obj) in memo:
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     939             # we only care about session the first pass thru
#     940             pickler._session = False
# --> 941         StockPickler.save_dict(pickler, obj)
#     942         log.info("# D2")
#     943     return
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     685                     "args[0] from __newobj__ args has the wrong class")
#     686             args = args[1:]
# --> 687             save(cls)
#     688             save(args)
#     689             write(NEWOBJ)
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/site-packages/dill/_dill.py in save_type(pickler, obj)
#    1388        #print ("%s\n%s" % (obj.__bases__, obj.__dict__))
#    1389         name = getattr(obj, '__qualname__', getattr(obj, '__name__', None))
# -> 1390         StockPickler.save_global(pickler, obj, name=name)
#    1391         log.info("# T4")
#    1392     return
#
# /usr/local/Caskroom/miniconda/base/envs/migration/lib/python3.8/pickle.py in save_global(self, obj, name)
#    1068             obj2, parent = _getattribute(module, name)
#    1069         except (ImportError, KeyError, AttributeError):
# -> 1070             raise PicklingError(
#    1071                 "Can't pickle %r: it's not found as %s.%s" %
#    1072                 (obj, module_name, name)) from None
#
# PicklingError: Can't pickle <class 'botocore.client.S3'>: it's not found as botocore.client.S3
